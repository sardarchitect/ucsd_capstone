# %%
import os
import cv2 as cv
import matplotlib.pyplot as plt

# %%
def generate_frames(video_file):
    cap = cv.VideoCapture(video_file)
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        if not ret:
            break
        
        yield frame
    video.release()
    
def plot_image(image, size=12):
    plt.figure(figsize=(size, size))
    plt.imshow(image[...,::-1])
    plt.show()

# %%
SOURCE_VIDEO_PATH = '../virat/videos/VIRAT_S_000002.mp4'

# %%
frame_iterator = iter(generate_frames(video_file=SOURCE_VIDEO_PATH))

# %%
frame = next(frame_iterator)
plot_image(frame, 16)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 2
#       1 import torch
# ----> 2 model = torch.hub.load('ultralytics/yolov5', 'custom', WEIGHTS_PATH, device=0)
#
# NameError: name 'WEIGHTS_PATH' is not defined
